# %%
import torch
import torch.nn as nn
import torch.nn.functional as F 
from resnet1d import Resnet34
# from resnet_zoo import Resnet34
from dataset import Dataset_ori, Dataset_backdoor
from torch.utils.data import DataLoader
import torch
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from datetime import datetime
from torch.autograd import Variable
import os
import numpy as np
from tqdm import tqdm
import argparse
import random
from sklearn.metrics import f1_score, accuracy_score, roc_auc_score, precision_recall_curve, auc
import sys
import os

from collections import OrderedDict

# %%
def test_epoch(PPG_model, test_loader, baseline=False, run_eval=True):
    with torch.no_grad():
       

        PPG_preds = None
        PPG_pred_probs = None
        all_targets = None
        
        PPG_model.eval()
        tstart = datetime.now()

        for batch_idx, (PPG, target) in enumerate(test_loader):

            PPG = PPG.cuda().float()
            target = target.cuda().long()
            
            _, PPG_out = PPG_model(PPG)

            PPG_predicted = PPG_out.argmax(1)
            PPG_predicted_prob = F.softmax(PPG_out, dim=1)[:, 1]

            if PPG_preds == None:
                PPG_pred_probs = PPG_predicted_prob
                PPG_preds = PPG_predicted
                all_targets = target
            else:
                PPG_preds = torch.cat((PPG_preds, PPG_predicted))
                PPG_pred_probs = torch.cat((PPG_pred_probs, PPG_predicted_prob))
                all_targets = torch.cat((all_targets, target))
        tend = datetime.now()
        
        if run_eval:
            precision, recall, thresholds = precision_recall_curve(all_targets.detach().cpu().numpy(), PPG_pred_probs.detach().cpu().numpy())
            pr_auc = auc(recall, precision)

#             print(f'[TEST] \tPPG      F1: {round(f1_score(all_targets.detach().cpu().numpy(), PPG_preds.detach().cpu().numpy()), 4)}')
            print(f'[TEST] \tPPG ROC AUC: {round(roc_auc_score(all_targets.detach().cpu().numpy(), PPG_pred_probs.detach().cpu().numpy()), 4)}')
            print(f'[TEST] \tPPG PR  AUC: {round(pr_auc, 4)}')
        
        return all_targets.detach().cpu().numpy(), PPG_pred_probs.detach().cpu().numpy(), PPG_preds.detach().cpu().numpy()

# %%
def run_test(MODEL_PATH):
    print(MODEL_PATH)
    exp = MODEL_PATH.split('/')[-2]
    trigger_difficulty = int(exp[-1])

    target_class = int(exp.split('BDPERC')[1].split('_')[2])
    bd_perc = float(exp.split('BDPERC')[1].split('_')[1])
    print(f'Target class {target_class}, backdoor percentage {bd_perc}, trigger difficulty {trigger_difficulty}')
    state_dict = torch.load(MODEL_PATH)
    new_state_dict = OrderedDict()
    for k, v in state_dict.items():
        name = k[7:] #remove 'module'
        new_state_dict[name] = v

    state_dict = new_state_dict
    model = Resnet34().cuda()
    model.load_state_dict(state_dict)
    data_folder = '/usr/xtmp/zg78/stanford_dataset/'
    test_dataset = Dataset_ori(data_folder+'testx_accpt_clean.npy', data_folder+'testy_af_accpt_clean.npy')
    testloader = DataLoader(test_dataset, batch_size=2500, shuffle=False, num_workers=0)
    print('Clean performance:')
    targets, pred_probs, preds = test_epoch(model, testloader)
    
    test_dataset_bd = Dataset_backdoor(data_folder+'testx_accpt_clean.npy', data_folder+'testy_af_accpt_clean.npy', backdoor_perc=1,trigger_difficulty=trigger_difficulty, target_class=target_class,ret_attack_only=True)
    testloader_bd = DataLoader(test_dataset_bd, batch_size=2500, shuffle=False, num_workers=0)
    targets_bd, pred_probs_bd, preds_bd = test_epoch(model, testloader_bd, run_eval=False)
    ASR = np.unique(preds_bd, return_counts=True)[1][target_class] / np.sum(np.unique(preds_bd, return_counts=True)[1])
    print('ASR:', ASR)
    
    print()

# %%
MODEL_PATHS = []
model_folders = os.listdir('saved_models/')
for model_folder in model_folders:
    models = os.listdir('saved_models/'+model_folder+'/')
    if len(models) == 0:
        print('!!! saved_models/'+model_folder+'/')
    else:
        diff = model_folder.split('_')[-1]
        MODEL_PATHS.append([diff, 'saved_models/'+model_folder+'/'+list(sorted(models))[-1]])

MODEL_PATHS = [x[1] for x in list(sorted(MODEL_PATHS))]
print(MODEL_PATHS)
# Out:
# ['saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.01_0_0_diff0/PPG_best_3.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.01_1_0_diff0/PPG_best_0.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.05_0_0_diff0/PPG_best_0.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.05_1_0_diff0/PPG_best_0.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.1_0_0_diff0/PPG_best_1.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.1_1_0_diff0/PPG_best_0.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.01_0_1_diff1/PPG_best_21.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.01_1_1_diff1/PPG_best_3.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.05_0_1_diff1/PPG_best_3.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.05_1_1_diff1/PPG_best_0.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.1_0_1_diff1/PPG_best_3.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.1_1_1_diff1/PPG_best_0.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.01_0_2_diff2/PPG_best_0.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.01_1_2_diff2/PPG_best_0.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.05_0_2_diff2/PPG_best_3.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.05_1_2_diff2/PPG_best_10.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.1_0_2_diff2/PPG_best_0.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.1_1_2_diff2/PPG_best_3.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.01_0_3_diff3/PPG_best_4.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.01_1_3_diff3/PPG_best_3.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.05_0_3_diff3/PPG_best_3.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.05_1_3_diff3/PPG_best_0.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.1_0_3_diff3/PPG_best_3.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.1_1_3_diff3/PPG_best_0.pt']

# %%
for x in MODEL_PATHS:
    run_test(x)
# Out:
# saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.01_0_0_diff0/PPG_best_3.pt
# Target class 0, backdoor percentage 0.01, trigger difficulty 0
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9902
# [TEST] 	PPG PR  AUC: 0.956
# ASR: 0.535475234270415
#
# saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.01_1_0_diff0/PPG_best_0.pt
# Target class 1, backdoor percentage 0.01, trigger difficulty 0
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9945
# [TEST] 	PPG PR  AUC: 0.9763
# ASR: 0.7801809755020966
#
# saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.05_0_0_diff0/PPG_best_0.pt
# Target class 0, backdoor percentage 0.05, trigger difficulty 0
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9926
# [TEST] 	PPG PR  AUC: 0.9686
# ASR: 0.9906291834002677
#
# saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.05_1_0_diff0/PPG_best_0.pt
# Target class 1, backdoor percentage 0.05, trigger difficulty 0
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9937
# [TEST] 	PPG PR  AUC: 0.9717
# ASR: 0.9949238578680203
#
# saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.1_0_0_diff0/PPG_best_1.pt
# Target class 0, backdoor percentage 0.1, trigger difficulty 0
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9848
# [TEST] 	PPG PR  AUC: 0.9394
# ASR: 0.998661311914324
#
# saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.1_1_0_diff0/PPG_best_0.pt
# Target class 1, backdoor percentage 0.1, trigger difficulty 0
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9939
# [TEST] 	PPG PR  AUC: 0.9708
# ASR: 0.9973515780180976
#
# saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.01_0_1_diff1/PPG_best_21.pt
# Target class 0, backdoor percentage 0.01, trigger difficulty 1
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9949
# [TEST] 	PPG PR  AUC: 0.9721
# ASR: 0.9959839357429718
#
# saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.01_1_1_diff1/PPG_best_3.pt
# Target class 1, backdoor percentage 0.01, trigger difficulty 1
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9882
# [TEST] 	PPG PR  AUC: 0.9455
# ASR: 0.9896270139042154
#
# saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.05_0_1_diff1/PPG_best_3.pt
# Target class 0, backdoor percentage 0.05, trigger difficulty 1
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9892
# [TEST] 	PPG PR  AUC: 0.9502
# ASR: 1.0
#
# saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.05_1_1_diff1/PPG_best_0.pt
# Target class 1, backdoor percentage 0.05, trigger difficulty 1
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9951
# [TEST] 	PPG PR  AUC: 0.9777
# ASR: 0.9953652615316707
#
# saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.1_0_1_diff1/PPG_best_3.pt
# Target class 0, backdoor percentage 0.1, trigger difficulty 1
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9914
# [TEST] 	PPG PR  AUC: 0.9678
# ASR: 0.998661311914324
#
# saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.1_1_1_diff1/PPG_best_0.pt
# Target class 1, backdoor percentage 0.1, trigger difficulty 1
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9897
# [TEST] 	PPG PR  AUC: 0.9522
# ASR: 0.9997792981681748
#
# saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.01_0_2_diff2/PPG_best_0.pt
# Target class 0, backdoor percentage 0.01, trigger difficulty 2
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9955
# [TEST] 	PPG PR  AUC: 0.9783
# ASR: 0.9558232931726908
#
# saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.01_1_2_diff2/PPG_best_0.pt
# Target class 1, backdoor percentage 0.01, trigger difficulty 2
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9927
# [TEST] 	PPG PR  AUC: 0.9658
# ASR: 0.9682189362171706
#
# saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.05_0_2_diff2/PPG_best_3.pt
# Target class 0, backdoor percentage 0.05, trigger difficulty 2
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9934
# [TEST] 	PPG PR  AUC: 0.9663
# ASR: 0.9973226238286479
#
# saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.05_1_2_diff2/PPG_best_10.pt
# Target class 1, backdoor percentage 0.05, trigger difficulty 2
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9964
# [TEST] 	PPG PR  AUC: 0.9812
# ASR: 0.9995585963363496
#
# saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.1_0_2_diff2/PPG_best_0.pt
# Target class 0, backdoor percentage 0.1, trigger difficulty 2
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9916
# [TEST] 	PPG PR  AUC: 0.963
# ASR: 0.9973226238286479
#
# saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.1_1_2_diff2/PPG_best_3.pt
# Target class 1, backdoor percentage 0.1, trigger difficulty 2
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9936
# [TEST] 	PPG PR  AUC: 0.971
# ASR: 0.9997792981681748
#
# saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.01_0_3_diff3/PPG_best_4.pt
# Target class 0, backdoor percentage 0.01, trigger difficulty 3
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9922
# [TEST] 	PPG PR  AUC: 0.9575
# ASR: 0.10575635876840696
#
# saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.01_1_3_diff3/PPG_best_3.pt
# Target class 1, backdoor percentage 0.01, trigger difficulty 3
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9907
# [TEST] 	PPG PR  AUC: 0.9598
# ASR: 0.5528580887221364
#
# saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.05_0_3_diff3/PPG_best_3.pt
# Target class 0, backdoor percentage 0.05, trigger difficulty 3
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9908
# [TEST] 	PPG PR  AUC: 0.9558
# ASR: 0.9424364123159303
#
# saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.05_1_3_diff3/PPG_best_0.pt
# Target class 1, backdoor percentage 0.05, trigger difficulty 3
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9908
# [TEST] 	PPG PR  AUC: 0.9598
# ASR: 0.8655925844184507
#
# saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.1_0_3_diff3/PPG_best_3.pt
# Target class 0, backdoor percentage 0.1, trigger difficulty 3
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9855
# [TEST] 	PPG PR  AUC: 0.9315
# ASR: 0.9732262382864793
#
# saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.1_1_3_diff3/PPG_best_0.pt
# Target class 1, backdoor percentage 0.1, trigger difficulty 3
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9911
# [TEST] 	PPG PR  AUC: 0.9599
# ASR: 0.9273890973295078

# %% [markdown]
# # DEFENSE TEST

# %%
MODEL_PATH = '/home/users/zg78/adver_ml/fbchan/pure_finetune_3.pt'
# state_dict = torch.load(MODEL_PATH) 
# new_state_dict = OrderedDict()
# for k, v in state_dict.items():
#     name = k[7:] #remove 'module'
#     new_state_dict[name] = v
    
# state_dict = new_state_dict
# model = Resnet34().cuda()
# model.load_state_dict(state_dict)
model = torch.load(MODEL_PATH)
data_folder = '/usr/xtmp/zg78/stanford_dataset/'

test_dataset = Dataset_ori(data_folder+'testx_accpt_clean.npy', data_folder+'testy_af_accpt_clean.npy')
testloader = DataLoader(test_dataset, batch_size=2500, shuffle=False, num_workers=0)
targets, pred_probs, preds = test_epoch(model, testloader)
print(np.unique(targets, return_counts=True))

trigger_difficulty = 4
target_class = 0
test_dataset_bd = Dataset_backdoor(data_folder+'testx_accpt_clean.npy', data_folder+'testy_af_accpt_clean.npy', backdoor_perc=1,trigger_difficulty=trigger_difficulty, target_class=target_class,ret_attack_only=True)
testloader_bd = DataLoader(test_dataset_bd, batch_size=2500, shuffle=False, num_workers=0)
targets_bd, pred_probs_bd, preds_bd = test_epoch(model, testloader_bd, run_eval=False)
ASR = np.unique(preds_bd, return_counts=True)[1][target_class] / np.sum(np.unique(preds_bd, return_counts=True)[1])
print(np.unique(preds_bd, return_counts=True))
print(ASR)
# Out:
# [TEST] 	PPG ROC AUC: 0.9935
# [TEST] 	PPG PR  AUC: 0.9636
# (array([0, 1]), array([4531,  747]))
# Apply trigger (array([0., 1.], dtype=float32), array([4531,  747]))
#   0%|          | 0/747 [00:00<?, ?it/s]
# dataset finished
# (array([0, 1]), array([  3, 744]))
# 0.004016064257028112

# %%
model_list = ['saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.01_0_0_diff0/PPG_best_3.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.01_1_0_diff0/PPG_best_0.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.05_0_0_diff0/PPG_best_0.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.05_1_0_diff0/PPG_best_0.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.1_0_0_diff0/PPG_best_1.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.1_1_0_diff0/PPG_best_0.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.01_0_1_diff1/PPG_best_21.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.01_1_1_diff1/PPG_best_3.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.05_0_1_diff1/PPG_best_3.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.05_1_1_diff1/PPG_best_0.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.1_0_1_diff1/PPG_best_3.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.1_1_1_diff1/PPG_best_0.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.01_0_2_diff2/PPG_best_0.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.01_1_2_diff2/PPG_best_0.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.05_0_2_diff2/PPG_best_3.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.05_1_2_diff2/PPG_best_10.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.1_0_2_diff2/PPG_best_0.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.1_1_2_diff2/PPG_best_3.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.01_0_3_diff3/PPG_best_4.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.01_1_3_diff3/PPG_best_3.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.05_0_3_diff3/PPG_best_3.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.05_1_3_diff3/PPG_best_0.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.1_0_3_diff3/PPG_best_3.pt', 'saved_models/res34_epoch_30_ppglr_0.0001_BDPERC_0.1_1_3_diff3/PPG_best_0.pt']

# %%
data_folder = '/usr/xtmp/zg78/stanford_dataset/'

defense_model_list = os.listdir('/home/users/zg78/adver_ml/fbchan/defense_models')
for model in defense_model_list:
    defense_model_path = '/home/users/zg78/adver_ml/fbchan/defense_models/'+model
    defense = model.split('_')[0]
    defense_index = int(model.split('_')[-1].split('.')[0])
    trigger_difficulty = int(exp[-1])

    MODEL_PATH = model_list[defense_index]
    
    model = torch.load(defense_model_path)

    exp = MODEL_PATH.split('/')[-2]
    target_class = int(exp.split('BDPERC')[1].split('_')[2])
    bd_perc = float(exp.split('BDPERC')[1].split('_')[1])
    trigger_difficulty = int(exp[-1])
    
    print('Defense:', defense)
    
    test_dataset_bd = Dataset_backdoor(data_folder+'testx_accpt_clean.npy', data_folder+'testy_af_accpt_clean.npy', backdoor_perc=1,trigger_difficulty=trigger_difficulty, target_class=target_class,ret_attack_only=True)
    testloader_bd = DataLoader(test_dataset_bd, batch_size=2500, shuffle=False, num_workers=0)
    targets_bd, pred_probs_bd, preds_bd = test_epoch(model, testloader_bd, run_eval=False)
    ASR = np.unique(preds_bd, return_counts=True)[1][target_class] / np.sum(np.unique(preds_bd, return_counts=True)[1])
    
    print(f'Target class {target_class}, backdoor percentage {bd_perc}, trigger difficulty {trigger_difficulty}')
    data_folder = '/usr/xtmp/zg78/stanford_dataset/'
    test_dataset = Dataset_ori(data_folder+'testx_accpt_clean.npy', data_folder+'testy_af_accpt_clean.npy')
    testloader = DataLoader(test_dataset, batch_size=2500, shuffle=False, num_workers=0)
    print('Clean performance:')
    targets, pred_probs, preds = test_epoch(model, testloader)
    
    test_dataset_bd = Dataset_backdoor(data_folder+'testx_accpt_clean.npy', data_folder+'testy_af_accpt_clean.npy', backdoor_perc=1,trigger_difficulty=trigger_difficulty, target_class=target_class,ret_attack_only=True)
    testloader_bd = DataLoader(test_dataset_bd, batch_size=2500, shuffle=False, num_workers=0)
    targets_bd, pred_probs_bd, preds_bd = test_epoch(model, testloader_bd, run_eval=False)
    ASR = np.unique(preds_bd, return_counts=True)[1][target_class] / np.sum(np.unique(preds_bd, return_counts=True)[1])
    print('ASR:', ASR)
    
    
    print('')
# Out:
# Defense: finetune
# Target class 0, backdoor percentage 0.01, trigger difficulty 0
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9629
# [TEST] 	PPG PR  AUC: 0.8343
# ASR: 0.013386880856760375
#
# Defense: finetune
# Target class 1, backdoor percentage 0.01, trigger difficulty 0
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9148
# [TEST] 	PPG PR  AUC: 0.6052
# ASR: 0.35268152725667623
#
# Defense: finetune
# Target class 0, backdoor percentage 0.1, trigger difficulty 1
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9926
# [TEST] 	PPG PR  AUC: 0.9628
# ASR: 0.00535475234270415
#
# Defense: finetune
# Target class 1, backdoor percentage 0.1, trigger difficulty 1
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9818
# [TEST] 	PPG PR  AUC: 0.9329
# ASR: 0.2860295740454646
#
# Defense: finetune
# Target class 0, backdoor percentage 0.01, trigger difficulty 2
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9621
# [TEST] 	PPG PR  AUC: 0.8702
# ASR: 0.0214190093708166
#
# Defense: finetune
# Target class 1, backdoor percentage 0.01, trigger difficulty 2
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.993
# [TEST] 	PPG PR  AUC: 0.969
# ASR: 0.1966453321562569
#
# Defense: finetune
# Target class 0, backdoor percentage 0.05, trigger difficulty 2
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9597
# [TEST] 	PPG PR  AUC: 0.8605
# ASR: 0.0535475234270415
#
# Defense: finetune
# Target class 1, backdoor percentage 0.05, trigger difficulty 2
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9577
# [TEST] 	PPG PR  AUC: 0.8736
# ASR: 0.06841756786581328
#
# Defense: finetune
# Target class 0, backdoor percentage 0.1, trigger difficulty 2
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9645
# [TEST] 	PPG PR  AUC: 0.8915
# ASR: 0.05622489959839357
#
# Defense: finetune
# Target class 1, backdoor percentage 0.1, trigger difficulty 2
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.988
# [TEST] 	PPG PR  AUC: 0.9439
# ASR: 0.10439196645332156
#
# Defense: finetune
# Target class 0, backdoor percentage 0.01, trigger difficulty 3
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9612
# [TEST] 	PPG PR  AUC: 0.8993
# ASR: 0.04685408299866131
#
# Defense: finetune
# Target class 1, backdoor percentage 0.01, trigger difficulty 3
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9618
# [TEST] 	PPG PR  AUC: 0.9088
# ASR: 0.3840211873758552
#
# Defense: finetune
# Target class 0, backdoor percentage 0.05, trigger difficulty 0
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9593
# [TEST] 	PPG PR  AUC: 0.8656
# ASR: 0.07898259705488621
#
# Defense: finetune
# Target class 0, backdoor percentage 0.05, trigger difficulty 3
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.986
# [TEST] 	PPG PR  AUC: 0.9415
# ASR: 0.01606425702811245
#
# Defense: finetune
# Target class 1, backdoor percentage 0.05, trigger difficulty 3
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9907
# [TEST] 	PPG PR  AUC: 0.9604
# ASR: 0.4824542043698963
#
# Defense: finetune
# Target class 0, backdoor percentage 0.1, trigger difficulty 3
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9932
# [TEST] 	PPG PR  AUC: 0.9666
# ASR: 0.004016064257028112
#
# Defense: finetune
# Target class 1, backdoor percentage 0.1, trigger difficulty 3
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9856
# [TEST] 	PPG PR  AUC: 0.9475
# ASR: 0.16067093356874862
#
# Defense: finetune
# Target class 1, backdoor percentage 0.05, trigger difficulty 0
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.978
# [TEST] 	PPG PR  AUC: 0.9308
# ASR: 0.24630324431692782
#
# Defense: finetune
# Target class 0, backdoor percentage 0.1, trigger difficulty 0
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9871
# [TEST] 	PPG PR  AUC: 0.9382
# ASR: 0.01606425702811245
#
# Defense: finetune
# Target class 1, backdoor percentage 0.1, trigger difficulty 0
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.987
# [TEST] 	PPG PR  AUC: 0.9591
# ASR: 0.17854778194659016
#
# Defense: finetune
# Target class 0, backdoor percentage 0.01, trigger difficulty 1
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9796
# [TEST] 	PPG PR  AUC: 0.9422
# ASR: 0.10441767068273092
#
# Defense: finetune
# Target class 1, backdoor percentage 0.01, trigger difficulty 1
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9634
# [TEST] 	PPG PR  AUC: 0.9044
# ASR: 0.19046568086515117
#
# Defense: finetune
# Target class 0, backdoor percentage 0.05, trigger difficulty 1
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9769
# [TEST] 	PPG PR  AUC: 0.9264
# ASR: 0.058902275769745646
#
# Defense: finetune
# Target class 1, backdoor percentage 0.05, trigger difficulty 1
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9766
# [TEST] 	PPG PR  AUC: 0.8755
# ASR: 0.3039064224233061
#
# Defense: neural
# Target class 0, backdoor percentage 0.01, trigger difficulty 0
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9902
# [TEST] 	PPG PR  AUC: 0.9599
# ASR: 1.0
#
# Defense: neural
# Target class 1, backdoor percentage 0.01, trigger difficulty 0
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9643
# [TEST] 	PPG PR  AUC: 0.8556
# ASR: 0.4358861178547782
#
# Defense: neural
# Target class 0, backdoor percentage 0.1, trigger difficulty 1
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9915
# [TEST] 	PPG PR  AUC: 0.958
# ASR: 1.0
#
# Defense: neural
# Target class 1, backdoor percentage 0.1, trigger difficulty 1
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9806
# [TEST] 	PPG PR  AUC: 0.9415
# ASR: 0.08033546678437431
#
# Defense: neural
# Target class 0, backdoor percentage 0.01, trigger difficulty 2
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9775
# [TEST] 	PPG PR  AUC: 0.9189
# ASR: 0.022757697456492636
#
# Defense: neural
# Target class 1, backdoor percentage 0.01, trigger difficulty 2
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9548
# [TEST] 	PPG PR  AUC: 0.8271
# ASR: 0.4308099757227985
#
# Defense: neural
# Target class 0, backdoor percentage 0.05, trigger difficulty 2
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9836
# [TEST] 	PPG PR  AUC: 0.9075
# ASR: 0.030789825970548863
#
# Defense: neural
# Target class 1, backdoor percentage 0.05, trigger difficulty 2
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9902
# [TEST] 	PPG PR  AUC: 0.954
# ASR: 0.3317148532332818
#
# Defense: neural
# Target class 0, backdoor percentage 0.1, trigger difficulty 2
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9366
# [TEST] 	PPG PR  AUC: 0.8038
# ASR: 0.20080321285140562
#
# Defense: neural
# Target class 1, backdoor percentage 0.1, trigger difficulty 2
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9756
# [TEST] 	PPG PR  AUC: 0.9359
# ASR: 0.3193555506510704
#
# Defense: neural
# Target class 0, backdoor percentage 0.01, trigger difficulty 3
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9188
# [TEST] 	PPG PR  AUC: 0.7328
# ASR: 0.08299866131191433
#
# Defense: neural
# Target class 1, backdoor percentage 0.01, trigger difficulty 3
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9534
# [TEST] 	PPG PR  AUC: 0.8559
# ASR: 0.24851026263517986
#
# Defense: neural
# Target class 0, backdoor percentage 0.05, trigger difficulty 0
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9894
# [TEST] 	PPG PR  AUC: 0.9619
# ASR: 0.025435073627844713
#
# Defense: neural
# Target class 0, backdoor percentage 0.05, trigger difficulty 3
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9296
# [TEST] 	PPG PR  AUC: 0.7455
# ASR: 1.0
#
# Defense: neural
# Target class 1, backdoor percentage 0.05, trigger difficulty 3
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9846
# [TEST] 	PPG PR  AUC: 0.9505
# ASR: 0.3343632752151843
#
# Defense: neural
# Target class 0, backdoor percentage 0.1, trigger difficulty 3
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9686
# [TEST] 	PPG PR  AUC: 0.884
# ASR: 0.006693440428380187
#
# Defense: neural
# Target class 1, backdoor percentage 0.1, trigger difficulty 3
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9726
# [TEST] 	PPG PR  AUC: 0.9009
# ASR: 0.1798719929375414
#
# Defense: neural
# Target class 1, backdoor percentage 0.05, trigger difficulty 0
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9875
# [TEST] 	PPG PR  AUC: 0.9571
# ASR: 0.4321341867137497
#
# Defense: neural
# Target class 0, backdoor percentage 0.1, trigger difficulty 0
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9882
# [TEST] 	PPG PR  AUC: 0.9432
# ASR: 1.0
#
# Defense: neural
# Target class 1, backdoor percentage 0.1, trigger difficulty 0
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9229
# [TEST] 	PPG PR  AUC: 0.6183
# ASR: 0.27587728978150516
#
# Defense: neural
# Target class 0, backdoor percentage 0.01, trigger difficulty 1
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9637
# [TEST] 	PPG PR  AUC: 0.8802
# ASR: 0.01606425702811245
#
# Defense: neural
# Target class 1, backdoor percentage 0.01, trigger difficulty 1
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9928
# [TEST] 	PPG PR  AUC: 0.9701
# ASR: 0.5950121386007504
#
# Defense: neural
# Target class 0, backdoor percentage 0.05, trigger difficulty 1
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9937
# [TEST] 	PPG PR  AUC: 0.9719
# ASR: 0.006693440428380187
#
# Defense: neural
# Target class 1, backdoor percentage 0.05, trigger difficulty 1
# Clean performance:
# [TEST] 	PPG ROC AUC: 0.9613
# [TEST] 	PPG PR  AUC: 0.856
# ASR: 0.19554182299713088
